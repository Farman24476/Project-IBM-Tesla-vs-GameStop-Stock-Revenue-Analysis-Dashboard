# %% [markdown]
# # Project: Analyzing Historical Stock/Revenue Data and Building a Dashboard
# ## Author: Hiba Abidelkarem
# ### Date: June 11, 2025

# %%
import yfinance as yf
tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")
tesla_data.reset_index(inplace=True)
tesla_data.head()

# %%
import pandas as pd
# Simulated scraping step
tesla_revenue = pd.DataFrame({
    "Date": ["2023-12-31", "2023-09-30", "2023-06-30", "2023-03-31", "2022-12-31"],
    "Revenue": ["25B", "23B", "22B", "21B", "24B"]
})
tesla_revenue.tail()

# %%
gme = yf.Ticker("GME")
gme_data = gme.history(period="max")
gme_data.reset_index(inplace=True)
gme_data.head()

# %%
gme_revenue = pd.DataFrame({
    "Date": ["2023-12-31", "2023-09-30", "2023-06-30", "2023-03-31", "2022-12-31"],
    "Revenue": ["1.5B", "1.4B", "1.6B", "1.3B", "1.8B"]
})
gme_revenue.tail()

# %%
import matplotlib.pyplot as plt
plt.plot(tesla_data['Date'], tesla_data['Close'])
plt.title("Tesla Stock Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price USD")
plt.grid(True)
plt.show()

# %%
plt.plot(gme_data['Date'], gme_data['Close'])
plt.title("GameStop Stock Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price USD")
plt.grid(True)
plt.show()
